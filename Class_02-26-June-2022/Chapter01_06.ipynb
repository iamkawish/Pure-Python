# %%
# Cell Execute -------->Shift + Enter      >> Executes current cell and adds a new cell below
 #---------->          Ctrl+ Enter         >> It only executes the current cell

# %%
# Introduction to Programming in Python

# %%
#  Topics:
#        >Why python?
#        >Interpreter
#        >Compiler
#        >Variables
#        > Print Function
#        > Naming Conventions
#        >Operator

# %%
# Mode of Translator: python is interpreter based

# %%
                           # Types of Values
    # Numeric Values :
                #    --->   Whole Number (integers) python >>(int)
                #                    Example 2,4,5, 100,-3,-6
                #    --->   Decimal Number (decimals)   python >> (float)
                #                    Example 2.3 45.0
    # Alphabets:
                #    ---> Char/words/Sentence/Paragraph (String) python (str)
                #                    Example "Hello WOrld"
                #                             "1000"
                #                             'Hello'
                #                              '100'
                #                            '''Hello'''
                #                            '''100'''
    # Boolean Values:
             #       ---> true/false in python   (True/False)

# %%
print("Hello world")
print("100")
print('Hello WOrld')
print('100')
print('''Hello World''')
print('''100''')
# Out:
# Hello world
# 100
# Hello WOrld
# 100
# Hello World
# 100

# %%
print(100)
print(-3)
# Out:
# 100
# -3

# %%
print(34.56)
print(45.0)
# Out:
# 34.56
# 45.0

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
type(6)
# Out:
# int

# %%
print("Piaic",10,4.566,True)
# Out:
# Piaic 10 4.566 True

# %%
a=("Piaic",10,4.566,True)

# %%
type(a)
# Out:
# tuple

# %%
print("PIAIC",16,3.366,False,sep="+")
# Out:
# PIAIC+16+3.366+False

# %% [markdown]
# #        Escape Character in python

# %%
# \n -------------> New Line
print("I am a Student of BSSE.\nI am Learning in VU")
# Out:
# I am a Student of BSSE.
# I am Learning in VU

# %%
#\n ----------> New Tab 
print("I am a Student of BSSE.\t\tI am Learning in VU")
# Out:
# I am a Student of BSSE.		I am Learning in VU

# %%
# Variable in Python
#            -> Variables are called identifers
#            -> Variable are containers / reservoires to store values

# %%
mark=90


#       marks >> variable name / identifier
#      '='   >> Assignment Operator
#      90    >> an integers value
#      An integer value 90 is assigned to a variable marks.

# %%
# address
id(mark)
# Out:
# 2945249399952

# %% [markdown]
# # Variables name Convention
#             # Logically be a true representation of your value
#             # Illegal
#         #    -  any word that is used by python like for, while, Else, Class, True, False   >>>>Reserved Word/Keyword
#         #    - Variable name will not begin with a number
#         #                1stStudent
#         #                12
#         #    - Special Character can not be used in variable name
#         #                name@a
#         #                Friend-ship
#         #                n@me

# %% [raw]
# # Reserved Word
# False             	def	                if	         raise
# None	            del	               import	     return
# True	            elif	           in	         try
# and	                else	           is	         while
# as	                except	           lambda	     with
# assert	            finally	           nonlocal	     yield
# break           	for	               not           or
# class	            form	           pass          continue	     global

# %% [raw]
# # Operators
# #           Addition(+)
# #          Subtraction(-)
# #          Multiplication(*)
# #          Division(/)---->float division
# #          Division(//)-----> Integer division
# #          Power(**)
# #          Modulus(%)

# %%
3+4
# Out:
# 7

# %%
3-4
# Out:
# -1

# %%
4/2
# Out:
# 2.0

# %%
4//2
# Out:
# 2

# %%
3*4
# Out:
# 12

# %%
3**3
# Out:
# 27

# %%
4%2
# Out:
# 0

# %% [markdown]
# Python Operator
#         There are Seven Operator in Python
#              -Assignment Operator
#              -Arithematic Operator
#              -Comparision Operator
#              -Logical operator
#              -Identify Operator
#              -Membership Operator
#              -Bitwise Operator
#                 # This Link is show Seven operator
#                 #     https://www.scaler.com/topics/python/operators-in-python/

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)
